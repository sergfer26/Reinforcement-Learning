# %%
from duel import duel
from board import Board
#from agent_tabular_qlearning import Agent_TQL as atql
#from agent_value_iteration import AgentVI as avi
from base_agent import remap_stringkeys, remap_values
import json
import numpy as np
import pandas as pd
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
from human import Human as human

from minmax_agent import MinMax_Agent as mma
from agent_mc import AgentMC as amc
from agent_random import Random as random_agent

# %%
agentQ = amc()
agentV = random_agent()
agentQ.values = remap_stringkeys(json.load(open("values.txt")))
agentQ.rewards = remap_stringkeys(json.load(open("rewards.txt")))

# %%
playerX = agentV
playerO = agentQ
playerO.rewards = remap_values(playerO.rewards)
playerO.role = 'O'

# %%
games = 1000
prob = []
for k in range(1,games+1):
    winner_value = duel(playerX, playerO, show=True)
    if winner_value == 2:
        playerO.wins += 1
        aux = playerX
        playerX = playerO
        playerO = aux
        playerX.role = 'X'
        playerO.role = 'O'
        try:
            playerO.rewards = remap_values(playerO.rewards)
            playerX.rewards = remap_values(playerX.rewards)
            playerX.values = remap_values(playerX.values)
            playerO.values = remap_values(playerO.values)
        except AttributeError:
            pass
        
    elif winner_value == 1:
        playerX.wins += 1
        
    if k % 10 == 0:
        prob.append(agentQ.wins/k)
# Out:
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  | X
#
# Accion Aleatoria!
#
#               | X |
#             ----------
#               | O | O
#             ----------
#               |  | X
#
#
#              X | X |
#             ----------
#               | O | O
#             ----------
#               |  | X
#
#
#              X | X |
#             ----------
#              O | O | O
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
# Accion Aleatoria!
#
#               |  |
#             ----------
#               | O |
#             ----------
#               | X | X
#
#
#              O |  |
#             ----------
#               | O |
#             ----------
#               | X | X
#
#
#              O |  |
#             ----------
#               | O |
#             ----------
#              X | X | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
# Accion Aleatoria!
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#              X |  | O
#             ----------
#               |  | O
#
#
#               | X |
#             ----------
#              X | X | O
#             ----------
#               |  | O
#
#
#               | X | O
#             ----------
#              X | X | O
#             ----------
#               |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#              O |  | O
#
#
#              X | X | X
#             ----------
#               |  |
#             ----------
#              O |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
# Accion Aleatoria!
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
# Accion Aleatoria!
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
# Accion Aleatoria!
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
# Accion Aleatoria!
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
# Accion Aleatoria!
#
#               | X |
#             ----------
#               |  |
#             ----------
#               | O |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               | O | X
#
#
#               | X | O
#             ----------
#               |  |
#             ----------
#               | O | X
#
#
#               | X | O
#             ----------
#               |  | X
#             ----------
#               | O | X
#
#
#               | X | O
#             ----------
#               | O | X
#             ----------
#               | O | X
#
#
#               | X | O
#             ----------
#              X | O | X
#             ----------
#               | O | X
#
# Accion Aleatoria!
#
#              O | X | O
#             ----------
#              X | O | X
#             ----------
#               | O | X
#
#
#              O | X | O
#             ----------
#              X | O | X
#             ----------
#              X | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
# Accion Aleatoria!
#
#               | X |
#             ----------
#               |  |
#             ----------
#              O |  |
#
#
#              X | X |
#             ----------
#               |  |
#             ----------
#              O |  |
#
#
#              X | X |
#             ----------
#               | O |
#             ----------
#              O |  |
#
#
#              X | X | X
#             ----------
#               | O |
#             ----------
#              O |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#               |  | X
#
#
#              O | X |
#             ----------
#              X |  | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O |  | X
#
#
#              O | X |
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#              O | X | X
#             ----------
#              X | X | O
#             ----------
#              O | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
# Accion Aleatoria!
#
#              O | X |
#             ----------
#              X | O |
#             ----------
#               |  |
#
#
#              O | X | X
#             ----------
#              X | O |
#             ----------
#               |  |
#
#
#              O | X | X
#             ----------
#              X | O |
#             ----------
#               |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  | X
#
#
#               | X |
#             ----------
#               | O | O
#             ----------
#               |  | X
#
#
#              X | X |
#             ----------
#               | O | O
#             ----------
#               |  | X
#
#
#              X | X |
#             ----------
#              O | O | O
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#              O |  | O
#
#
#              X | X | X
#             ----------
#               |  |
#             ----------
#              O |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               | O |
#             ----------
#               |  | O
#
#
#              X | X | X
#             ----------
#               | O |
#             ----------
#               |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
# Accion Aleatoria!
#
#               | X |
#             ----------
#               | O |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               | O |
#             ----------
#              X |  |
#
#
#               | X |
#             ----------
#              O | O |
#             ----------
#              X |  |
#
#
#               | X | X
#             ----------
#              O | O |
#             ----------
#              X |  |
#
#
#               | X | X
#             ----------
#              O | O | O
#             ----------
#              X |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#               | O |
#             ----------
#               |  | X
#
# Accion Aleatoria!
#
#               | O | X
#             ----------
#              X | O |
#             ----------
#               |  | X
#
#
#               | O | X
#             ----------
#              X | O |
#             ----------
#               | O | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X |  |
#             ----------
#               |  |
#
#
#              O | X |
#             ----------
#              X | O |
#             ----------
#               |  |
#
#
#              O | X | X
#             ----------
#              X | O |
#             ----------
#               |  |
#
#
#              O | X | X
#             ----------
#              X | O |
#             ----------
#               |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#              X |  | O
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#              X |  | O
#             ----------
#               |  | O
#
#
#               | X |
#             ----------
#              X | X | O
#             ----------
#               |  | O
#
#
#               | X | O
#             ----------
#              X | X | O
#             ----------
#               |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#              O |  | O
#
#
#              X | X | X
#             ----------
#               |  |
#             ----------
#              O |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               |  | O
#
# Accion Aleatoria!
#
#               | X | X
#             ----------
#              O |  |
#             ----------
#               |  | O
#
#
#              X | X | X
#             ----------
#              O |  |
#             ----------
#               |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               | O |
#             ----------
#               |  | O
#
#
#              X | X | X
#             ----------
#               | O |
#             ----------
#               |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  | O
#             ----------
#               |  | O
#
#
#              X | X | X
#             ----------
#               |  | O
#             ----------
#               |  | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               |  | O
#
#
#               | X | X
#             ----------
#               |  |
#             ----------
#               | O | O
#
#
#              X | X | X
#             ----------
#               |  |
#             ----------
#               | O | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  | X
#
#
#               | X |
#             ----------
#               | O | O
#             ----------
#               |  | X
#
#
#              X | X |
#             ----------
#               | O | O
#             ----------
#               |  | X
#
#
#              X | X |
#             ----------
#              O | O | O
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
# Accion Aleatoria!
#
#               | X |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#               |  |
#
#
#               | X |
#             ----------
#               |  | O
#             ----------
#              X |  |
#
#
#               | X |
#             ----------
#              O |  | O
#             ----------
#              X |  |
#
#
#               | X |
#             ----------
#              O |  | O
#             ----------
#              X | X |
#
#
#               | X |
#             ----------
#              O |  | O
#             ----------
#              X | X | O
#
#
#               | X |
#             ----------
#              O | X | O
#             ----------
#              X | X | O
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
# Accion Aleatoria!
#
#               | X |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               | X |
#             ----------
#              O | O |
#             ----------
#               |  | X
#
#
#               | X |
#             ----------
#              O | O | X
# ...
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
# Accion Aleatoria!
#
#               |  |
#             ----------
#               | O |
#             ----------
#               | X | X
#
#
#              O |  |
#             ----------
#               | O |
#             ----------
#               | X | X
#
#
#              O |  |
#             ----------
#               | O |
#             ----------
#              X | X | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               | X |
#             ----------
#               |  |
#
#
#               | O |
#             ----------
#               | X |
#             ----------
#               |  |
#
#
#               | O |
#             ----------
#               | X | X
#             ----------
#               |  |
#
#
#               | O |
#             ----------
#               | X | X
#             ----------
#              O |  |
#
#
#               | O |
#             ----------
#              X | X | X
#             ----------
#              O |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
# Accion Aleatoria!
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               | X | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#              O | X | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#              O | X | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  |
#
#
#               |  |
#             ----------
#               |  |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O |
#             ----------
#               |  | X
#
#
#               |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  |
#             ----------
#               | O | X
#             ----------
#               |  | X
#
#
#              O |  | X
#             ----------
#               | O | X
#             ----------
#               |  | X

# %%
vals = [(k,v) for k, v in agentQ.values.items() if v != 0]

# %%
vals
# Out:
# [(0, 0.07825781221860911),
#  (3, -0.03425840548273993),
#  (45, -0.04417062772526575),
#  (780, 1.5),
#  (861, -1.5),
#  (165, -0.0074786580044826495),
#  (2657, 0.9705882352941176),
#  (3338, -1.5),
#  (81, 0.17010855164751587),
#  (87, 0.3173142497303823),
#  (88, 0.049479166666666664),
#  (1843, 0.75),
#  (33, -0.03170615758641741),
#  (34, 0.75),
#  (319, 0.046875),
#  (1, 0.17033216436146212),
#  (978, 0.1875),
#  (1185, 1.1785714285714286),
#  (3586, -1.5),
#  (163, 0.33848195011939775),
#  (172, 0.6838140980183776),
#  (5, 0.043965042106756606),
#  (46, 0.005681818181818182),
#  (308, 1.5),
#  (66, 0.75),
#  (1167, -1.5),
#  (144, -0.375),
#  (297, -0.025716145833333332),
#  (378, 0.05439453125),
#  (114, 0.6679519558956959),
#  (384, 0.111328125),
#  (1839, 0.75),
#  (936, 1.4108358985333076),
#  (1875, 0.7351613892163199),
#  (1507, -0.375),
#  (544, 1.5),
#  (2083, 1.5),
#  (900, 0.03470339756397449),
#  (834, -0.75),
#  (1797, 0.75),
#  (42, -0.09391643326911185),
#  (204, -0.009205898268398266),
#  (439, 1.5),
#  (205, 1.5),
#  (166, 0.6988829721709928),
#  (469, 0.75),
#  (32, 0.21838199358320945),
#  (1948, 1.5),
#  (1179, 0.6302953742685885),
#  (198, 0.15360140357285995),
#  (300, -0.08072916666666667),
#  (4264, -1.5),
#  (1788, 1.316860465116279),
#  (142, 0.09895833333333333),
#  (385, 0.2328125),
#  (1712, 0.5),
#  (1140, 0.298148547379647),
#  (907, -1.5),
#  (1877, 1.411764705882353),
#  (2660, -1.5),
#  (4180, -1.5),
#  (1758, 0.22916666666666666),
#  (316, 0.01171875),
#  (1722, 0.65625),
#  (933, 0.13636363636363635),
#  (1873, 0.6346255133755135),
#  (7499, 1.3),
#  (1191, 0.375),
#  (1145, -1.5),
#  (1723, 0.9375),
#  (226, 1.3269230769230775),
#  (1141, 0.5),
#  (902, 0.20192307692307693),
#  (3398, 1.5),
#  (1480, -0.1875),
#  (1777, -0.375),
#  (304, -0.10291666666666668),
#  (1407, 0.6448601787485869),
#  (298, -0.060546875),
#  (1193, 0.75),
#  (2815, 1.5),
#  (1272, 0.375),
#  (939, 0.7030622279506209),
#  (2145, 1.4196428571428572),
#  (3396, 0.75),
#  (2731, 0.75),
#  (1387, -1.5),
#  (7469, 1.5),
#  (3372, -1.5),
#  (10472, -1.5),
#  (1993, -0.75),
#  (941, 0.75),
#  (1789, 0.75),
#  (2741, 1.5),
#  (481, 0.1875),
#  (208, 0.5),
#  (194, 0.7245889927380312),
#  (203, 1.4134615384615385),
#  (2668, 0.75),
#  (10469, -0.75),
#  (2029, 0.75),
#  (1858, -0.75),
#  (905, -1.5),
#  (2819, 1.5),
#  (7463, 0.75),
#  (1202, 1.5),
#  (3571, 1.5),
#  (2495, 1.5),
#  (1767, 1.5),
#  (1851, 1.5),
#  (403, 1.5)]

# %%
agentQ.wins
# Out:
# 937

# %%
prob
# Out:
# [1.0,
#  0.9,
#  0.6,
#  0.525,
#  0.5,
#  0.5833333333333334,
#  0.6142857142857143,
#  0.6625,
#  0.7,
#  0.73,
#  0.7545454545454545,
#  0.775,
#  0.7923076923076923,
#  0.8071428571428572,
#  0.82,
#  0.81875,
#  0.7941176470588235,
#  0.7888888888888889,
#  0.7947368421052632,
#  0.805,
#  0.8142857142857143,
#  0.8227272727272728,
#  0.8304347826086956,
#  0.8333333333333334,
#  0.836,
#  0.8384615384615385,
#  0.8444444444444444,
#  0.8464285714285714,
#  0.8482758620689655,
#  0.8533333333333334,
#  0.8580645161290322,
#  0.8625,
#  0.8666666666666667,
#  0.8705882352941177,
#  0.8742857142857143,
#  0.8777777777777778,
#  0.8810810810810811,
#  0.8842105263157894,
#  0.8871794871794871,
#  0.89,
#  0.8926829268292683,
#  0.8952380952380953,
#  0.8976744186046511,
#  0.9,
#  0.9022222222222223,
#  0.9021739130434783,
#  0.9042553191489362,
#  0.90625,
#  0.9040816326530612,
#  0.906,
#  0.907843137254902,
#  0.9096153846153846,
#  0.9113207547169812,
#  0.912962962962963,
#  0.9145454545454546,
#  0.9160714285714285,
#  0.9175438596491228,
#  0.9155172413793103,
#  0.9169491525423729,
#  0.9166666666666666,
#  0.9147540983606557,
#  0.9129032258064517,
#  0.9142857142857143,
#  0.915625,
#  0.916923076923077,
#  0.9166666666666666,
#  0.9164179104477612,
#  0.9176470588235294,
#  0.9188405797101449,
#  0.92,
#  0.9211267605633803,
#  0.9222222222222223,
#  0.9232876712328767,
#  0.922972972972973,
#  0.9226666666666666,
#  0.9236842105263158,
#  0.9246753246753247,
#  0.9256410256410257,
#  0.9265822784810127,
#  0.9275,
#  0.928395061728395,
#  0.9292682926829269,
#  0.9301204819277108,
#  0.930952380952381,
#  0.9317647058823529,
#  0.9325581395348838,
#  0.9333333333333333,
#  0.9340909090909091,
#  0.9348314606741573,
#  0.9355555555555556,
#  0.932967032967033,
#  0.933695652173913,
#  0.9344086021505377,
#  0.9351063829787234,
#  0.9357894736842105,
#  0.934375,
#  0.9350515463917526,
#  0.9357142857142857,
#  0.9363636363636364,
#  0.937]

# %%
df = pd.DataFrame({ 'probabilidad' : prob})

figsize(11, 9)
df.plot(title='Probabilidad de que el agente Q-learning gane',color='r')
plt.xlabel("Simulaciones")
plt.ylabel("Probabilidad")
# Out:
# Text(0, 0.5, 'Probabilidad')
